# %%
# variables

number = 78

# %%
friends_name = ("sandhu","maria","maya","sundar","amal")
for i in friends_name :
 print(i)
# Out:
# sandhu
# maria
# maya
# sundar
# amal

# %%
data = ("enter your mark")
for i in data:
  if data =
  print(i)
# Out:
# 45
# 60
# 80
# 77
# 96

# %%
marks = (48,77,80,95,49)
if i in marks:
  print(i)
else:
# Out:
#   File "/tmp/ipython-input-2842564438.py", line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
sister_age = 60
print(sister_age)
print(type(sister_age))
# Out:
# 60
# <class 'int'>

# %%
data = " sandhiya "
print(data)
# Out:
#  sandhiya

# %%
school = " A.M.M.S "
print(school)
print(type(school))
# Out:
#  A.M.M.S
# <class 'str'>

# %%
marks = 75

if marks >= 40:
  print("great , you have passed the exam")
else:
  print("failed")
# Out:
# great , you have passed the exam

# %%
Age = input("enter your mom's age")
print(Age)
# Out:
# enter your mom's age50
# 50

# %%
marks = int(input("enter you marks"))
print(marks)
print(type(marks))
# Out:
# enter you marks99
# 99
# <class 'int'>

# %%
amount = 1000
if amount>=1100:
 print ("profit")
else:
 print ("loss")
# Out:
# loss

# %%
marks = int(input("enter your marks"))

if marks >= 90:
  print("A")
elif marks >= 70:
  print("B")
elif marks >= 50:
  print("C")
else:
  print("failed")
# Out:
# enter your marks70
# B

# %%
6 > 50 > 200
# Out:
# False

# %%
6 > 50 < 200
# Out:
# False

# %%
marks = [77,88,65,99,51]
print(marks)
print(type(marks))
print(len(marks))
print(marks[4])
# Out:
# [77, 88, 65, 99, 51]
# <class 'list'>
# 5
# 51

# %%
marks = 100

if marks >=90:
 print("A")
elif marks >=70:
 print("B")
elif marks >=50:
 print("C")
else:
 print("failed")
# Out:
# A

# %%
#integers

number = 17

# %%
number
# Out:
# 78

# %%
my_number = 78
print(my_number)   # integer
# Out:
# 78

# %%
weight = 45.9
print(weight)
print(type(weight))
# Out:
# 45.9
# <class 'float'>

# %%
my_data = "I am from Dolakhpur"
print(my_data)
# Out:
# I am from Dolakhpur

# %%
college = "APC College"
print(college)
# Out:
# APC College

# %%
print(type(college))
# Out:
# <class 'str'>

# %%
number of students = 135      # error varum
print(number of students)
# Out:
#   File "/tmp/ipython-input-626814143.py", line 1
#     number of students = 135
#            ^
# SyntaxError: invalid syntax

# %%
1styear_students = 45      # error varum
print(1styear_students)
# Out:
#   File "/tmp/ipython-input-268246624.py", line 1
#     1styear_students = 45
#     ^
# SyntaxError: invalid decimal literal

# %%
# integers, strings , float

# %%
success = True
print(success)
# Out:
# True

# %%
6 > 8
# Out:
# False

# %%
45 < 67
# Out:
# True

# %%
34 > 4
# Out:
# True

# %%
56 >= 56
# Out:
# True

# %%
56 <= 56
# Out:
# True

# %%
marks =  76

if marks >= 50:
  print("congrats , you have passed the exam")
else:
  print("sorry, you have failed")
# Out:
# congrats , you have passed the exam

# %%
val = "78"
print(type(val))
print(val)
# Out:
# <class 'str'>
# 78

# %%
marks = input("enter your marks ")
print(type(marks))     # "45"

my_marks = int(input("enter your marks "))
print(type(my_marks))   # 45
# Out:
# enter your marks 45
# <class 'str'>
# enter your marks 45
# <class 'int'>

# %%
val = int(input("hi, enter ur number "))
print(val)
#print(type(val)
# Out:
# hi, enter ur number 67
# 67

# %%
age = 56

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
6 < 100 <466
# Out:
# True

# %%
balance = int(input(" number kudu .."))

if balance >= 100:
  print("no need to recharge")
elif  balance >= 50  and balance < 100:
  print("recharge ")
else:
  print("re -activate sim")

# %% [markdown]
# Write a Python program that calculates the number of moles of a substance.
# The number of moles is calculated using the formula:
# number of moles = mass / molar mass
#
# Where:
# Mass is measured in grams
# Molar mass is measured in grams per mole

# %% [markdown]
# Example values for testing your program:
# Substance: Glucose
#
# Mass = 34.5 g
# Molar mass = 180 g/mol
#
# Your program should:
# Ask the user to enter the mass of the substance
#
# Ask the user to enter the molar mass
# Calculate the number of moles
#
# Print the result on the screen
# Bonus: Round the final answer to two decimal places.

# %%
a_mass = input()
a_molar_mass = input()

# %% [markdown]
# Write a Python program that calculates the molar mass of a compound made of carbon, hydrogen, and oxygen.
#
# The atomic masses are:
#
# Carbon (C) = 12 g/mol
#
# Hydrogen (H) = 1 g/mol
#
# Oxygen (O) = 16 g/mol
#
# The molar mass is calculated using the formula:

# %% [markdown]
# Data Strcutures

# %%
my_marks = [34,45,23,45,56]

print(my_marks)
# Out:
# [34, 45, 23, 45, 56]

# %%
print(type(my_marks))
# Out:
# <class 'list'>

# %%
print(my_marks[0])
# Out:
# 34

# %%
print(my_marks[1])
# Out:
# 45

# %%
print(my_marks[1:4])
# Out:
# [45, 23, 45]

# %%
##########################################-------------Data Types---------------################################################

# these are the different types of data which we use to communiccate with the machine

# numbers (natural numbers intergers, decimal numbers (float))

# strings (names, paragraphs, textual data)

# boolean (yes or no)  (True or False)

# DONT RUN THESE LINES IN A SINGLE CELL, RUN EACH LINE IN A SEPERATE CELL

print(132)       # integer

print(34.56)      # float

#strings
print("Sherlock Holmes")   # string, with characters

print('U r mine')     # string

print('342.5')          # string this is also a string, since it is under quotes, either single or double quotes

print("342")          # string, this is also a string, since it is under quotes, either single or double quotes

print('True')        # string

print('False')       # String

#boolean
print(True)        # boolean, True or False

print(False)       # boolean, True or False

print(4<5)          # basic comparison ( ==, < ,>,<=,>=), leads to either True or False , which is boolean data type

print(4 <= 5)          # basic comparison ( ==, < ,>,<=,>=), leads to either True or False , which is boolean data type (LESS THAN OR Equals)

print(40 >= 52)        # basic comparison ( ==, < ,>,<=,>=), leads to either True or False , which is boolean data type (Greater than OR Equals)

print(25 == 34)          # basic comparison ( ==, < ,>,<=,>=), leads to either True or False , which is boolean data type


#####################################################-------VARIABLES--------##################################################



score  =  132       # variable , storing data in memory inoder to process it, but we will asssign a name to that stored entity
                    # twins example,,,, value like 10 is stored in two different memory locations,
                    # a=10       , a is stored in different location
                    # b=10
                    # here a and b are like twins , with same entity (lookalike) but stored in different locations ,
                    # and called with different names call variables (a, b)

#--------------------------------------------------Rules --------------------------------------
                           #### Case sensitive

#print(Score)        # Case sensitive (uppercase,, lowercase), this will throw an error, if you run it,
                     # since , score is different from Score
                     #  we are using S (capital S) instead of small s, so it will throw an error

print(score)        # now it will work


                          #### assigning variable

#my weight   = 85         # wont work as variable, since you have space inbetween the words which u used for variable declaration

# 23myWeight          # wont work,   dont start a variable name with number

my_weight  =  34.56  # will work

#My_weight             # will work

#myWeight               # will work

print(my_weight)

######################################################


#name  =  "Abdul Kalam"    # string

#print(name)





# Data Structures

# Conditional statements

# Loops

# Functions
# Out:
# 132
# 34.56
# Sherlock Holmes
# U r mine
# 342.5
# 342
# True
# False
# True
# False
# True
# True
# False
# False
# 132
# 34.56

# %%
100college = "IIT Madras"  # throw error, dont start a variable name with number or special characters
# Out:
#   File "/tmp/ipython-input-1365530072.py", line 1
#     100college = "IIT Madras"  # throw error, dont start a variable name with number or special characters
#       ^
# SyntaxError: invalid decimal literal

# %%
a100college = "IIT Madras"  # wont throw error, dont start a variable name with number
print(  a100college)
# Out:
# IIT Madras

# %%
address = "TamilNadu"

# %%
# slicing
address[2:5]    # from index 2 to 5, m to l, slicing wont consider upper index, upper index munnadi value dha yeduthukum
# Out:
# 'mil'

# %%
address[3:7]
# Out:
# 'ilNa'

# %%
address[3:]    # 3 index landhi , yellame
# Out:
# 'ilNadu'

# %%
address[:6]    # upper index 5 varakum, starting landhi
# Out:
# 'TamilN'

# %%
address[:]     # yellame, staring to end
# Out:
# 'TamilNadu'

# %%
address[0:7:2]  # inge 2 andradhu step size
 #TamilNadu, 1 landhi 8 varakum access ayidum, but step size 2, onu kaprom inonu skip panidum.,,"TamilNa" idhula aiNd dha varum
# Out:
# 'Tmla'

# %%
friends  = ['ramesh', 'suresh','ganesh','vignesh','Harish']

# %%
marks  = [23, 453434222, 67.56, 6, 34]

# %%
location = [43, "Chennai", 23.5,'65.22',34, False]

# %%
friends[1:3] # 1 and 2 comes
# Out:
# ['suresh', 'ganesh']

# %%
li = [3,'watson',43,45,34,45,3,45,3]

# %%
li[1:5]
#output is a list again, ipo andha list la irukara index 1 irukara element'watson' ange landhi ,2nd ,3rd,4th index elements varum
# Out:
# ['watson', 43, 45, 34]
